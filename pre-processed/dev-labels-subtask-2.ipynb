# %%
import pandas as pd
import numpy as np
import os
import regex as re
import spacy as sy
import string
from urllib.parse import urlparse
from nltk.tokenize import TweetTokenizer

nlp_en = sy.load('en_core_web_sm')
all_stopwords = nlp_en.Defaults.stop_words

# %%
filename = '/Users/arjunkhanchandani/Desktop/semeval2023task3bundle-v4/data/en/dev-labels-subtask-2.txt'
dev_sub2_df = pd.read_csv(filename, header=None, sep='\t', names=['id', 'genre'])
print(dev_sub2_df.head())
# Out:
#           id                                              genre
# 0  820791520  Political,Fairness_and_equality,Policy_prescri...
# 1  821040551  Political,Capacity_and_resources,Policy_prescr...
# 2  813552066  Public_opinion,Policy_prescription_and_evaluat...
# 3  817176202  Political,External_regulation_and_reputation,P...
# 4  820419869  Public_opinion,Political,External_regulation_a...

# %%
dir_name = '/Users/arjunkhanchandani/Desktop/semeval2023task3bundle-v4/data/en/dev-articles-subtask-2'

article_df = pd.DataFrame()

numbers = list()
headlines = list()
articles = list()

for file in os.walk(dir_name):
    for filename in file[2]:
        
        number = re.findall('[0-9]+', filename)
        numbers.append(number[0])
        x = dir_name + '/' + filename
        # print(number)
        article = ''
        with open(x) as f:
            lines = f.readlines()
            for i in range(len(lines)):
                if i==0:
                    headline = lines[0]
                    headlines.append(headline)
                elif lines[i]=="\n":
                    continue
                else:
                    # print()
                    article = article + '' + lines[i]
        articles.append(article)
            
article_df['id'] = numbers
article_df['headlines'] = headlines
article_df['articles'] = articles

article_df = article_df.astype({'id': 'int32'})

# %%
dev_sub2_df
# Out:
#            id                                              genre
# 0   820791520  Political,Fairness_and_equality,Policy_prescri...
# 1   821040551  Political,Capacity_and_resources,Policy_prescr...
# 2   813552066  Public_opinion,Policy_prescription_and_evaluat...
# 3   817176202  Political,External_regulation_and_reputation,P...
# 4   820419869  Public_opinion,Political,External_regulation_a...
# ..        ...                                                ...
# 78  829815104  Political,Crime_and_punishment,Fairness_and_eq...
# 79  817147979  Policy_prescription_and_evaluation,Political,L...
# 80  813623212  Policy_prescription_and_evaluation,Political,L...
# 81  832948083  Crime_and_punishment,Political,Legality_Consti...
# 82  813953273  Political,Morality,Crime_and_punishment,Qualit...
#
# [83 rows x 2 columns]

# %%
train_df = dev_sub2_df.set_index('id').join(article_df.set_index('id'))
print(train_df.isnull().sum())

train_df
# Out:
# genre        0
# headlines    0
# articles     0
# dtype: int64
#                                                        genre  \
# id
# 820791520  Political,Fairness_and_equality,Policy_prescri...
# 821040551  Political,Capacity_and_resources,Policy_prescr...
# 813552066  Public_opinion,Policy_prescription_and_evaluat...
# 817176202  Political,External_regulation_and_reputation,P...
# 820419869  Public_opinion,Political,External_regulation_a...
# ...                                                      ...
# 829815104  Political,Crime_and_punishment,Fairness_and_eq...
# 817147979  Policy_prescription_and_evaluation,Political,L...
# 813623212  Policy_prescription_and_evaluation,Political,L...
# 832948083  Crime_and_punishment,Political,Legality_Consti...
# 813953273  Political,Morality,Crime_and_punishment,Qualit...
#
#                                                    headlines  \
# id
# 820791520                         George III Lost America.\n
# 821040551  Queen Elizabeth Would Be Evacuated in Event of...
# 813552066  You insult us, ambassador: Woody Johnson flagr...
# 817176202  The British People, as Well as the Politicians...
# 820419869  No break from Brexit: RT takes a look at lates...
# ...                                                      ...
# 829815104                          Brussels Shows Its Fear\n
# 817147979                            BREXIT OR BRINO: U.K.\n
# 813623212  'Wishful thinking': Tory MPs dismiss May's hop...
# 832948083  Mueller concludes Russia-Trump probe; lawmaker...
# 813953273  RICHARD LITTLEJOHN: The capital sees its first...
#
#                                                     articles
# id
# 820791520  Theresa May Could Lose the United Kingdom Over...
# 821040551  If Britain leaves the European Union without a...
# 813552066  With three months until Britain leaves the Eur...
# 817176202  The British Parliament just handed Prime Minis...
# 820419869  As British MPs are told that their February br...
# ...                                                      ...
# 829815104  Hungarian Prime Minister Viktor Orban has been...
# 817147979  Deep State Strikes Back—And Misses.\nGood Omen...
# 813623212  Jeremy Hunt insisted Theresa May can still sal...
# 832948083  Mueller concludes Russia-Trump probe; lawmaker...
# 813953273  Tudor Simionov was killed when he tried to pre...
#
# [83 rows x 3 columns]

# %%
def preprocessing(x, y, df):
    
    pos_tags_final_text = list()
    er_final_text = list()
    preprocessed_text = list()

    for x in df.loc[:,y]:

        tokenizer = TweetTokenizer()
        #tokenizing
        doc = tokenizer.tokenize(x)
        
        # removing links
        tokens = [token for token in doc if not urlparse(token).scheme]
        x = ' '.join(tokens)
        doc = nlp_en(x)
        
        # removing punctuation and white space
        tokens = [token.orth_ for token in doc if not token.is_punct | token.is_space]    
        x = ' '.join(tokens)
        
        # lower case
        x = x.lower()
        doc = nlp_en(x)

        # lemmatization
        tokens = [word.lemma_ for word in doc]   
        x = ' '.join(tokens)
        doc = nlp_en(x)  
        
        # removing punctuation and white space
        tokens = [token.orth_ for token in doc if not token.is_punct | token.is_space]    
        x = ' '.join(tokens)
        doc = nlp_en(x)
        
        # removing individual letters
        tokens = [word.text for word in doc if len(word)>=2]
        x = ' '.join(tokens)  
        # print(x)
        doc = nlp_en(x)
        
        # removing stop words
        tokens = [word for word in doc if not word in all_stopwords]
        list_of_strings  = [i.text for i in tokens]
        x = ' '.join(list_of_strings)
        doc = nlp_en(x)
        
        # Part of speech tagging
        pos_tags = [(i, i.tag_) for i in doc]
        pos_tags_final_text.append(pos_tags)
        
        # entity recognition tagging
        er =  [(i, i.label_, i.label) for i in doc.ents] 
        er_final_text.append(er)
        
        preprocessed_text.append(x)
        
    return pos_tags_final_text, er_final_text, preprocessed_text

# %%
pos_tags_final_headlines, er_final_headlines, preprocessed_headlines = preprocessing(headline, 'headlines', train_df)

train_df['preprocessed_headlines'] = preprocessed_headlines
train_df['pos_tags_headlines'] = pos_tags_final_headlines
train_df['er_tags_headlines'] = er_final_headlines

# %%
pos_tags_final_articles, er_final_articles, preprocessed_articles = preprocessing(article, 'articles', train_df)

train_df['preprocessed_articles'] = preprocessed_articles
train_df['pos_tags_articles'] = pos_tags_final_articles
train_df['er_tags_articles'] = er_final_articles

# %%
train_df.head()
# Out:
#                                                        genre  \
# id
# 820791520  Political,Fairness_and_equality,Policy_prescri...
# 821040551  Political,Capacity_and_resources,Policy_prescr...
# 813552066  Public_opinion,Policy_prescription_and_evaluat...
# 817176202  Political,External_regulation_and_reputation,P...
# 820419869  Public_opinion,Political,External_regulation_a...
#
#                                                    headlines  \
# id
# 820791520                         George III Lost America.\n
# 821040551  Queen Elizabeth Would Be Evacuated in Event of...
# 813552066  You insult us, ambassador: Woody Johnson flagr...
# 817176202  The British People, as Well as the Politicians...
# 820419869  No break from Brexit: RT takes a look at lates...
#
#                                                     articles  \
# id
# 820791520  Theresa May Could Lose the United Kingdom Over...
# 821040551  If Britain leaves the European Union without a...
# 813552066  With three months until Britain leaves the Eur...
# 817176202  The British Parliament just handed Prime Minis...
# 820419869  As British MPs are told that their February br...
#
#                                       preprocessed_headlines  \
# id
# 820791520                            george iii lose america
# 821040551  queen elizabeth would be evacuate in event of ...
# 813552066  you insult us ambassador woody johnson flagran...
# 817176202  the british people as well as the politician d...
# 820419869  no break from brexit rt take look at late deve...
#
#                                           pos_tags_headlines  \
# id
# 820791520  [(george, NNP), (iii, NNP), (lose, VB), (ameri...
# 821040551  [(queen, NNP), (elizabeth, NNP), (would, MD), ...
# 813552066  [(you, PRP), (insult, VBP), (us, NNP), (ambass...
# 817176202  [(the, DT), (british, JJ), (people, NNS), (as,...
# 820419869  [(no, DT), (break, NN), (from, IN), (brexit, N...
#
#                                            er_tags_headlines  \
# id
# 820791520  [((george, iii), PERSON, 380), ((america), GPE...
# 821040551  [((elizabeth), PERSON, 380), ((brexit, riot, r...
# 813552066  [((woody, johnson), PERSON, 380), ((peter), PE...
# 817176202                           [((british), NORP, 381)]
# 820419869                         [((brexit, rt), ORG, 383)]
#
#                                        preprocessed_articles  \
# id
# 820791520  theresa may could lose the united kingdom over...
# 821040551  if britain leave the european union without tr...
# 813552066  with three month until britain leave the europ...
# 817176202  the british parliament just hand prime ministe...
# 820419869  as british mp be tell that their february brea...
#
#                                            pos_tags_articles  \
# id
# 820791520  [(theresa, NN), (may, MD), (could, MD), (lose,...
# 821040551  [(if, IN), (britain, NNP), (leave, VBP), (the,...
# 813552066  [(with, IN), (three, CD), (month, NN), (until,...
# 817176202  [(the, DT), (british, JJ), (parliament, NNP), ...
# 820419869  [(as, IN), (british, NNP), (mp, NNP), (be, VB)...
#
#                                             er_tags_articles
# id
# 820791520  [((the, united, kingdom), GPE, 384), ((the, eu...
# 821040551  [((britain), GPE, 384), ((the, european, union...
# 813552066  [((three, month), DATE, 391), ((britain), GPE,...
# 817176202  [((british), NORP, 381), ((british), NORP, 381...
# 820419869  [((british), NORP, 381), ((february), DATE, 39...

# %%
# converting tweets_df into a csv file
filename = '/Users/arjunkhanchandani/Desktop/semeval2023task3bundle-v4/dev_subtask_2.csv'
train_df.to_csv(filename, index=True)
